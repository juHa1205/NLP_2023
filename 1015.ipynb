# %% [markdown]
# <a href="https://colab.research.google.com/github/juHa1205/NLP_2023/blob/main/1015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import randint

# %%
x = np.linspace(0,1,50) #0~1사이 50개 데이터
y1 = np.cos(4*np.pi*x) #np.pi는 파이값 입력할 때 사용 : 0~4파이 값의 코사인 y1
y2 = np.cos(4*np.pi*x)*np.exp(-2*x)

plt.plot(x,y1,'r-*',lw=1)
plt.plot(x,y2,'b--',lw=1)

# %%
x=np.linspace(1,10,20) #시작 끝 갯수
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y = randint(1,50,20)
y
# Out:
# array([ 9, 34, 26, 45,  8, 14, 26, 45, 46, 14,  7, 40, 17, 38, 33, 24,  8,
#        19,  9, 29])

# %%
plt.plot(y)
