# %% [markdown]
# <a href="https://colab.research.google.com/github/juHa1205/NLP_2023/blob/main/1218.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import randint

# %%
x = np.linspace(0,1,50) #0~1사이 50개 데이터
y1 = np.cos(4*np.pi*x) #np.pi는 파이값 입력할 때 사용 : 0~4파이 값의 코사인 y1
y2 = np.cos(4*np.pi*x)*np.exp(-2*x)

plt.plot(x,y1,'r-*',lw=1)
plt.plot(x,y2,'b--',lw=1)

# %%
x = np.linspace(0,1,50)
y1 = np.cos(4*np.pi*x)
y2 = np.cos(4*np.pi*x)*np.exp(-2*x)

fig = plt.figure() #직접 Figure 객체를 생성
ax = fig.subplots() # 직접 axes를 생성
ax.plot(x,y1,'r-*',lw=1) #생성된 axes에 대한 plot() 멤버 직접 호출
ax.plot(x,y2,'b--',lw=1)

# %%
x = np.linspace(0,1,50)
y1 = np.cos(4*np.pi*x)
y2 = np.cos(4*np.pi*x)*np.exp(-2*x)

fig.ax = plt.subplots() #plt.subplots() 편의 함수는 Figure 객체를 생성하고 Figure.subplots()를 호출하여 리턴
ax.plot(x,y1,'r-*',lw=1)
ax.plot(x,y2,'b--',lw=1)

# %%
x
# Out:
# array([0.        , 0.02040816, 0.04081633, 0.06122449, 0.08163265,
#        0.10204082, 0.12244898, 0.14285714, 0.16326531, 0.18367347,
#        0.20408163, 0.2244898 , 0.24489796, 0.26530612, 0.28571429,
#        0.30612245, 0.32653061, 0.34693878, 0.36734694, 0.3877551 ,
#        0.40816327, 0.42857143, 0.44897959, 0.46938776, 0.48979592,
#        0.51020408, 0.53061224, 0.55102041, 0.57142857, 0.59183673,
#        0.6122449 , 0.63265306, 0.65306122, 0.67346939, 0.69387755,
#        0.71428571, 0.73469388, 0.75510204, 0.7755102 , 0.79591837,
#        0.81632653, 0.83673469, 0.85714286, 0.87755102, 0.89795918,
#        0.91836735, 0.93877551, 0.95918367, 0.97959184, 1.        ])

# %%
x.shape
# Out:
# (50,)

# %%
x=np.linspace(1,10,20) #시작 끝 갯수
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y = randint(1,50,20)
y
# Out:
# array([ 4, 31, 35, 33, 25, 37, 30,  5, 32, 30, 24, 30,  8,  5, 38, 32, 21,
#         8,  8, 36])

# %%
y.size
# Out:
# 20

# %%
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Enum',
#  'ExitStack',
#  'Figure',
#  'FigureBase',
#  'FigureCanvasBase',
#  'FigureManagerBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MouseButton',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotSpec',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_REPL_DISPLAYHOOK',
#  '_ReplDisplayHook',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_api',
#  '_auto_draw_if_interactive',
#  '_backend_mod',
# ...

# %%
plt.plot(y)

# %%
print(np.sort(y)) #random으로 출력된 y값을 순서대로 출력
# Out:
# [ 4  5  5  8  8  8 21 24 25 30 30 30 31 32 32 33 35 36 37 38]

# %%
y = np.sort(y)

# %%
plt.plot(y)

# %%
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y
# Out:
# array([ 4,  5,  5,  8,  8,  8, 21, 24, 25, 30, 30, 30, 31, 32, 32, 33, 35,
#        36, 37, 38])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'r')

# %%
plt.plot(x,y,'b')

# %%
plt.plot(x,y,'g')

# %%
plt.plot(x,y,'o')

# %%
plt.plot(x,y,'y')

# %%
plt.plot(x,y,color = 'r')

# %%
#axis title
plt.plot(x,y,'g')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Random Plot')
# Out:
# Text(0.5, 1.0, 'Random Plot')

# %%
#axis title
plt.plot(x,y,'g')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Random Plot')
plt.show()

# %%
plt.plot()
# Out:
# []

# %%
plt.subplot(1,2,1)
plt.subplot(1,2,2)
# Out:
# <Axes: >

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(x,y,'b')

# %%
y2 = y**2

# %%
y2
# Out:
# array([  16,   25,   25,   64,   64,   64,  441,  576,  625,  900,  900,
#         900,  961, 1024, 1024, 1089, 1225, 1296, 1369, 1444])

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(x,y2,'b')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'ro--')
plt.subplot(1,2,2)
plt.plot(x,y2,'b')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'ro')
plt.subplot(1,2,2)
plt.plot(x,y2,'b')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'ro')
plt.subplot(1,2,2)
plt.plot(x,y2,'b*')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'ro',markersize=2)

plt.subplot(1,2,2)
plt.plot(x,y2,'b+')

# %%
plt.scatter(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 20 artists>

# %%
from random import sample

# %%
data = sample(range(1,10000),10)
data
# Out:
# [4724, 3058, 9690, 4549, 4587, 4718, 8458, 1668, 1806, 5418]

# %%
plt.hist(data)
# Out:
# (array([2., 1., 0., 4., 1., 0., 0., 0., 1., 1.]),
#  array([1668. , 2470.2, 3272.4, 4074.6, 4876.8, 5679. , 6481.2, 7283.4,
#         8085.6, 8887.8, 9690. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data,rwidth = 0.8)
# Out:
# (array([2., 1., 0., 4., 1., 0., 0., 0., 1., 1.]),
#  array([1668. , 2470.2, 3272.4, 4074.6, 4876.8, 5679. , 6481.2, 7283.4,
#         8085.6, 8887.8, 9690. ]),
#  <BarContainer object of 10 artists>)

# %%
[np.random.normal(0,std,100) for std in range(1,10)]
# Out:
# [array([ 0.22462877, -1.05539799, -0.06481871,  0.2194024 , -0.59532547,
#         -0.36210662,  0.4337762 ,  0.77400445, -0.5993667 ,  0.24191904,
#          0.23982549,  0.86492045,  1.93868817, -0.18045398,  1.24254522,
#          0.21658626, -1.00220269,  1.16817673,  0.88228928,  0.36869682,
#          1.01004598, -1.93203337,  0.32615283,  0.55842304, -0.27544397,
#         -0.69464217, -0.15816195,  0.67223442,  2.02758684, -0.49960264,
#          0.48506522, -0.40509627,  0.08236925, -0.71591585,  0.46131862,
#          1.68060083,  0.27908771, -0.02036704,  1.33313927, -0.38099947,
#         -0.8024604 , -0.09514719, -1.43952723,  0.48212365, -1.23768218,
#          0.57568372,  0.90480417,  0.77576239, -0.56134207, -0.42601439,
#          1.1906167 ,  0.51749143,  1.9062429 ,  0.56564861, -1.57631196,
#          0.18740544, -2.01729385,  0.45588727,  1.14365486, -0.26509295,
#         -2.16881655, -0.63714217,  0.11922667, -1.72013346,  0.36087189,
# ...

# %%
data
# Out:
# [4724, 3058, 9690, 4549, 4587, 4718, 8458, 1668, 1806, 5418]

# %%
plt.boxplot(data,vert=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14c754395d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14c7543ae10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14c75438a50>],
#  'medians': [<matplotlib.lines.Line2D at 0x14c754403d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14c73a31590>],
#  'means': []}

# %%
plt.boxplot(data,vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14c754a9bd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14c754aae90>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x14c75487a10>],
#  'medians': [<matplotlib.lines.Line2D at 0x14c754bc3d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14c754bce90>],
#  'means': []}

# %%
data = [np.random.normal(0,std,100) for std in range(1,3)]

# %%
data
# Out:
# [array([ 0.15340801, -0.48839511, -0.26072672, -2.19123359, -1.00411785,
#          0.84607109,  0.98437067, -0.60887929,  0.57310372, -1.00731979,
#         -0.520101  , -1.49431266, -0.55535113,  0.0168576 ,  1.48090698,
#          0.94153181, -1.07538598,  1.06457052,  0.80992956,  1.390537  ,
#         -0.71855601, -0.29374292,  1.33513529, -0.21219931, -0.94014441,
#          0.57678002,  0.02726841,  1.34043074,  1.14324446,  0.13084712,
#          1.21892924, -1.64591474,  0.15922315, -0.5188022 , -0.37479891,
#         -0.30764331,  0.7071886 , -1.19233951,  0.52197648, -0.9842642 ,
#         -1.86674172,  0.48211361,  1.07822075,  0.41455266, -1.6182022 ,
#          0.56757198, -0.81489098,  0.68886285,  0.38921573, -0.74176306,
#          0.31677513, -0.31951597,  0.86954116,  0.79514678,  0.66411771,
#         -0.26355282, -0.45219324,  0.32815516, -0.7139433 ,  0.29764478,
#         -0.80558735, -0.71161994,  0.59836485, -1.09363743,  1.38089135,
# ...

# %%
plt.boxplot(data,vert = True, patch_artist = True)
plt.show()

# %%
import pandas as pd

# %%
data = {
    'apple': [3,1,4,5],
    'orange': [1,5,6,8],
    '': [11,12,13,14]
}

# %%
data
# Out:
# {'apple': [3, 1, 4, 5], 'orange': [1, 5, 6, 8], '': [11, 12, 13, 14]}

# %%
type(data) #dic. tpye임을 알 수 있다
# Out:
# dict

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    apple  orange
# 0      3       1  11
# 1      1       5  12
# 2      4       6  13
# 3      5       8  14

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['apple']
# Out:
# 0    3
# 1    1
# 2    4
# 3    5
# Name: apple, dtype: int64

# %%
type(df['apple'])
# Out:
# pandas.core.series.Series

# %%
for i in df.columns:
    print(i)
# Out:
# apple
# orange

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   apple   4 non-null      int64
#  1   orange  4 non-null      int64
#  2           4 non-null      int64
# dtypes: int64(3)
# memory usage: 224.0 bytes

# %%
# csv 포멧의 큰 데이타를 pandas DataFrame를 이용해서 데이타를 확인하고 필요시 가공

# %%
df = pd.read_csv('nba.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-425e38d14a5a> in <cell line: 1>()
# ----> 1 df = pd.read_csv('nba.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df
# Out:
#    apple  orange
# 0      3       1  11
# 1      1       5  12
# 2      4       6  13
# 3      5       8  14

# %%
df.head()
# Out:
#    apple  orange
# 0      3       1  11
# 1      1       5  12
# 2      4       6  13
# 3      5       8  14

# %%
df.tail(10)
# Out:
#                Name       Team  Number Position   Age Height  Weight  \
# 448  Gordon Hayward  Utah Jazz    20.0       SF  26.0    6-8   226.0
# 449     Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0
# 450      Joe Ingles  Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451   Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453    Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454       Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455    Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0
# 456     Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0
# 457             NaN        NaN     NaN      NaN   NaN    NaN     NaN
#
#       College      Salary
# 448    Butler  15409570.0
# 449      Duke   1348440.0
# 450       NaN   2050000.0
# 451    Dayton    981348.0
# 452  Kentucky   2239800.0
# 453    Butler   2433333.0
# ...

# %%
df = pd.read_csv('nba.csv',index_col = 'Name')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fec1f4ed7250> in <cell line: 1>()
# ----> 1 df = pd.read_csv('nba.csv',index_col = 'Name')
#       2 df
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # movie data

# %%
df = pd.read_csv('IMDB-Movie-Data.csv',index_col = 'Rank')
df
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
# ...                       ...                       ...
# 996      Secret in Their Eyes       Crime,Drama,Mystery
# 997           Hostel: Part II                    Horror
# 998    Step Up 2: The Streets       Drama,Music,Romance
# 999              Search Party          Adventure,Comedy
# 1000               Nine Lives     Comedy,Family,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df.tail()
# Out:
#                        Title                  Genre  \
# Rank
# 996     Secret in Their Eyes    Crime,Drama,Mystery
# 997          Hostel: Part II                 Horror
# 998   Step Up 2: The Streets    Drama,Music,Romance
# 999             Search Party       Adventure,Comedy
# 1000              Nine Lives  Comedy,Family,Fantasy
#
#                                             Description          Director  \
# Rank
# 996   A tight-knit team of rising investigators, alo...         Billy Ray
# 997   Three American college students studying abroa...          Eli Roth
# 998   Romantic sparks occur between two dance studen...        Jon M. Chu
# 999   A pair of friends embark on a mission to reuni...    Scot Armstrong
# 1000  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                  Actors  Year  \
# Rank
# 996   Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               1000 non-null   object
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 93.8+ KB

# %%
df.duplicated()
# Out:
# Rank
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000    False
# Length: 1000, dtype: bool

# %%
sum(df.duplicated())
# Out:
# 0

# %%
df1 = pd.concat([df,df])

# %%
df1
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
# ...                       ...                       ...
# 996      Secret in Their Eyes       Crime,Drama,Mystery
# 997           Hostel: Part II                    Horror
# 998    Step Up 2: The Streets       Drama,Music,Romance
# 999              Search Party          Adventure,Comedy
# 1000               Nine Lives     Comedy,Family,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df1.duplicated().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of Rank
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 996      True
# 997      True
# 998      True
# 999      True
# 1000     True
# Length: 2000, dtype: bool>

# %%
df2 = df1.drop_duplicates()

# %%
df2
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
# ...                       ...                       ...
# 996      Secret in Their Eyes       Crime,Drama,Mystery
# 997           Hostel: Part II                    Horror
# 998    Step Up 2: The Streets       Drama,Music,Romance
# 999              Search Party          Adventure,Comedy
# 1000               Nine Lives     Comedy,Family,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df2.shape
# Out:
# (1000, 11)

# %%
df1.shape
# Out:
# (2000, 11)

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.shape
# Out:
# (1000, 11)

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean   2012.783000         113.172000     6.723200  1.698083e+05
# std       3.205962          18.810908     0.945429  1.887626e+05
# min    2006.000000          66.000000     1.900000  6.100000e+01
# 25%    2010.000000         100.000000     6.200000  3.630900e+04
# 50%    2014.000000         111.000000     6.800000  1.107990e+05
# 75%    2016.000000         123.000000     7.400000  2.399098e+05
# max    2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# 50%             47.985000   59.500000
# 75%            113.715000   72.000000
# max            936.630000  100.000000

# %%
col = df.columns

# %%
col
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
list(col)
# Out:
# ['Title',
#  'Genre',
#  'Description',
#  'Director',
#  'Actors',
#  'Year',
#  'Runtime (Minutes)',
#  'Rating',
#  'Votes',
#  'Revenue (Millions)',
#  'Metascore']

# %%
col1 = ['a','b','c','d','e','f','g','h','i','j','k']

# %%
df.columns = col1

# %%
df
# Out:
#                             a                         b  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
# ...                       ...                       ...
# 996      Secret in Their Eyes       Crime,Drama,Mystery
# 997           Hostel: Part II                    Horror
# 998    Step Up 2: The Streets       Drama,Music,Romance
# 999              Search Party          Adventure,Comedy
# 1000               Nine Lives     Comedy,Family,Fantasy
#
#                                                       c                     d  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df.columns = col

# %%
df
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
# ...                       ...                       ...
# 996      Secret in Their Eyes       Crime,Drama,Mystery
# 997           Hostel: Part II                    Horror
# 998    Step Up 2: The Streets       Drama,Music,Romance
# 999              Search Party          Adventure,Comedy
# 1000               Nine Lives     Comedy,Family,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df.rename(columns={'Runtime(Minutes)' : 'Runtime',
                  'Revenue (Millions)' : 'Revenue'},inplace = True)

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue', 'Metascore'],
#       dtype='object')

# %%
import numpy as np

# %%
df.isnull()
# Out:
#       Title  Genre  Description  Director  Actors   Year  Runtime (Minutes)  \
# Rank
# 1     False  False        False     False   False  False              False
# 2     False  False        False     False   False  False              False
# 3     False  False        False     False   False  False              False
# 4     False  False        False     False   False  False              False
# 5     False  False        False     False   False  False              False
# ...     ...    ...          ...       ...     ...    ...                ...
# 996   False  False        False     False   False  False              False
# 997   False  False        False     False   False  False              False
# 998   False  False        False     False   False  False              False
# 999   False  False        False     False   False  False              False
# 1000  False  False        False     False   False  False              False
#
#       Rating  Votes  Revenue  Metascore
# Rank
# ...

# %%
df.isnull().sum()
# Out:
# Title                  0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue              128
# Metascore             64
# dtype: int64

# %%
df.isna().sum()
# Out:
# Title                  0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue              128
# Metascore             64
# dtype: int64

# %%
df1 = df.dropna()
df1
# Out:
#                          Title                     Genre  \
# Rank
# 1      Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                   Prometheus  Adventure,Mystery,Sci-Fi
# 3                        Split           Horror,Thriller
# 4                         Sing   Animation,Comedy,Family
# 5                Suicide Squad  Action,Adventure,Fantasy
# ...                        ...                       ...
# 994   Resident Evil: Afterlife   Action,Adventure,Horror
# 995                  Project X                    Comedy
# 997            Hostel: Part II                    Horror
# 998     Step Up 2: The Streets       Drama,Music,Romance
# 1000                Nine Lives     Comedy,Family,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df1.shape
# Out:
# (838, 11)

# %%
df1.isnull().sum()
# Out:
# Title                0
# Genre                0
# Description          0
# Director             0
# Actors               0
# Year                 0
# Runtime (Minutes)    0
# Rating               0
# Votes                0
# Revenue              0
# Metascore            0
# dtype: int64

# %%
df2 = df.dropna(axis =1)

# %%
df2.head()
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# 3     Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 4     In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 5     A secret government agency recruits some of th...            David Ayer
#
#                                                  Actors  Year  \
# Rank
# 1     Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# ...

# %%
df2.shape
# Out:
# (1000, 9)

# %%
df3 = df.fillna(0)

# %%
df3.isna().sum()
# Out:
# Title                0
# Genre                0
# Description          0
# Director             0
# Actors               0
# Year                 0
# Runtime (Minutes)    0
# Rating               0
# Votes                0
# Revenue              0
# Metascore            0
# dtype: int64

# %%
revenue = df['Revenue']

# %%
revenue. head()
# Out:
# Rank
# 1    333.13
# 2    126.46
# 3    138.12
# 4    270.32
# 5    325.02
# Name: Revenue, dtype: float64

# %%
revenue. tail()
# Out:
# Rank
# 996       NaN
# 997     17.54
# 998     58.01
# 999       NaN
# 1000    19.64
# Name: Revenue, dtype: float64

# %%
revenue_mean = revenue.mean()

# %%
A = [1,2,3,4,5]
type(A)
# Out:
# list

# %%
A = np.array(A)

# %%
A
# Out:
# array([1, 2, 3, 4, 5])

# %%
A = A.mean()

# %%
A
# Out:
# 3.0

# %%
revenue_mean
# Out:
# 82.95637614678898

# %%
revenue.fillna(revenue_mean,inplace = True)

# %%
revenue.tail()
# Out:
# Rank
# 996     82.956376
# 997     17.540000
# 998     58.010000
# 999     82.956376
# 1000    19.640000
# Name: Revenue, dtype: float64

# %%
revenue.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue               0
# Metascore            64
# dtype: int64

# %%
metascore = df['Metascore']

# %%
metascore_mean = metascore.mean()

# %%
metascore.fillna(metascore_mean,inplace = True)

# %%
df.isnull().sum()
# Out:
# Title                0
# Genre                0
# Description          0
# Director             0
# Actors               0
# Year                 0
# Runtime (Minutes)    0
# Rating               0
# Votes                0
# Revenue              0
# Metascore            0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 11)

# %%
df
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
# ...                       ...                       ...
# 996      Secret in Their Eyes       Crime,Drama,Mystery
# 997           Hostel: Part II                    Horror
# 998    Step Up 2: The Streets       Drama,Music,Romance
# 999              Search Party          Adventure,Comedy
# 1000               Nine Lives     Comedy,Family,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df.isna().sum()
# Out:
# Title                0
# Genre                0
# Description          0
# Director             0
# Actors               0
# Year                 0
# Runtime (Minutes)    0
# Rating               0
# Votes                0
# Revenue              0
# Metascore            0
# dtype: int64

# %%
corrmat = df.corr(numeric_only = True)

# %%
corrmat
# Out:
#                        Year  Runtime (Minutes)    Rating     Votes   Revenue  \
# Year               1.000000          -0.164900 -0.211219 -0.411904 -0.117562
# Runtime (Minutes) -0.164900           1.000000  0.392214  0.407062  0.247834
# Rating            -0.211219           0.392214  1.000000  0.511537  0.189527
# Votes             -0.411904           0.407062  0.511537  1.000000  0.607941
# Revenue           -0.117562           0.247834  0.189527  0.607941  1.000000
# Metascore         -0.076077           0.202239  0.604723  0.318116  0.132304
#
#                    Metascore
# Year               -0.076077
# Runtime (Minutes)   0.202239
# Rating              0.604723
# Votes               0.318116
# Revenue             0.132304
# Metascore           1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(corrmat)
# Out:
# <Axes: >
